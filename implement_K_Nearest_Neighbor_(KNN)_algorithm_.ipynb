# %%
#Assigning features and label variables
# Feature variables
#First Feature
weather = [
    'Sunny', 'Overcast', 'Rain', 'Sunny', 'Rain',
    'Overcast', 'Sunny', 'Rain', 'Overcast', 'Sunny',
    'Rain', 'Overcast', 'Sunny', 'Rain', 'Sunny',
    'Overcast', 'Rain', 'Sunny', 'Overcast', 'Rain'
]
#Second Feature
temp = [
    'Hot', 'Mild', 'Cool', 'Mild', 'Hot',
    'Cool', 'Cool', 'Mild', 'Hot', 'Mild',
    'Cool', 'Mild', 'Hot', 'Mild', 'Cool',
    'Hot', 'Hot', 'Mild', 'Cool', 'Mild'
]


# Target variable
play = [
    'No', 'Yes', 'Yes', 'No', 'No',
    'Yes', 'No', 'Yes', 'Yes', 'No',
    'Yes', 'Yes', 'No', 'No', 'Yes',
    'Yes', 'No', 'Yes', 'Yes', 'Yes'
]


def BFS(node, visited):
      queue = []


      visited.add(node)
      queue.append(node)


      while queue:          # Creating loop to visit each node
        m = queue.pop(0)
        print(m, end = " ")


        for neighbour in graph[m]:
          if neighbour not in visited:
            visited.add(neighbour)
            queue.append(neighbour)


# driver code
visited = set()
graph = {}


add_vertex('A')
add_vertex('B')
add_vertex('C')
add_vertex('D')
add_vertex('E')


# Add the edges between the vertices by specifying the from and to vertex
add_edge('A', 'B')
add_edge('A', 'C')
add_edge('A', 'D')
add_edge('B', 'E')
add_edge('B', 'D')
add_edge('C', 'D')
add_edge('E', 'D')


print_graph()


print ("Internal representation of graph:", graph)
print("DFS Traversal:\n")


BFS("A",visited)

import pandas as pd


df = pd.DataFrame({
    'Weather': weather,
    'Temperature': temp,
    'Play': play
})


print(df)
# Out:
# A  ->  B
# A  ->  C
# A  ->  D
# B  ->  A
# B  ->  E
# B  ->  D
# C  ->  A
# C  ->  D
# D  ->  A
# D  ->  B
# D  ->  C
# D  ->  E
# E  ->  B
# E  ->  D
# Internal representation of graph: {'A': ['B', 'C', 'D'], 'B': ['A', 'E', 'D'], 'C': ['A', 'D'], 'D': ['A', 'B', 'C', 'E'], 'E': ['B', 'D']}
# DFS Traversal:
#
# A B C D E      Weather Temperature Play
# 0      Sunny         Hot   No
# 1   Overcast        Mild  Yes
# 2       Rain        Cool  Yes
# 3      Sunny        Mild   No
# 4       Rain         Hot   No
# 5   Overcast        Cool  Yes
# 6      Sunny        Cool   No
# 7       Rain        Mild  Yes
# 8   Overcast         Hot  Yes
# 9      Sunny        Mild   No
# 10      Rain        Cool  Yes
# 11  Overcast        Mild  Yes
# 12     Sunny         Hot   No
# 13      Rain        Mild   No
# 14     Sunny        Cool  Yes
# 15  Overcast         Hot  Yes
# 16      Rain         Hot   No
# 17     Sunny        Mild  Yes
# 18  Overcast        Cool  Yes
# 19      Rain        Mild  Yes
